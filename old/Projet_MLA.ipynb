# %% [markdown]
# # Projet MLA
# ## EXPLAINING AND HARNESSING ADVERSARIAL EXAMPLES

# %%
import numpy as np
#import torch

# %% [markdown]
# ## Expérience 1

# %% [markdown]
# ### Objectifs
# *

# %% [markdown]
# ### Réimplémentation de l'article

# %% [markdown]
# ### Évaluation
#
# #### Critère d'évaluation

# %% [markdown]
# #### Fiabilité du résultat
